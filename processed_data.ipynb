# %%
# import libraries
import io
import pandas as pd
import pandas.io.formats.excel
import numpy as np
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
from datetime import date
#import pysurveycto
import csv

today = date.today().strftime("%Y%m%d")

# %%
# Read in the excel file of the data contained in this repo
#df = pd.read_csv('Retailer_Survey_Chemtex_UGA_WIDE_14092021.csv', na_values = "NaN")

# %%
df = pd.read_csv('./data/raw_data/raw_data.csv', na_values = "NaN")

# %%
display(df.head())
# Out:
#             SubmissionDate                 starttime  \
# 0   Nov 8, 2021 5:19:49 PM    Nov 8, 2021 5:18:43 PM
# 1  Nov 10, 2021 9:08:52 PM   Nov 10, 2021 8:36:42 PM
# 2  Nov 13, 2021 4:13:39 AM  Nov 11, 2021 10:15:07 AM
# 3  Nov 13, 2021 4:15:40 AM   Nov 12, 2021 3:12:34 PM
# 4  Nov 13, 2021 7:06:23 AM   Nov 12, 2021 5:08:34 PM
#
#                     endtime                              deviceid  \
# 0    Nov 8, 2021 5:19:49 PM                                 (web)
# 1   Nov 10, 2021 9:08:29 PM                      712fced929bac385
# 2  Nov 11, 2021 10:52:51 AM  6BE46C2F-58A9-4B7A-A482-09B951A157AF
# 3   Nov 12, 2021 3:24:51 PM  6BE46C2F-58A9-4B7A-A482-09B951A157AF
# 4  Nov 13, 2021 12:43:14 AM                      cc93a8f522482023
#
#    subscriberid  simid  devicephonenum  location-Latitude  location-Longitude  \
# 0           NaN    NaN             NaN                NaN                 NaN
# 1           NaN    NaN             NaN           9.017858           38.834905
# 2           NaN    NaN             NaN           9.005792           38.788673
# 3           NaN    NaN             NaN           9.046247           38.731529
# 4           NaN    NaN             NaN                NaN                 NaN
#
#    location-Altitude  ...  rate_resp_k  enum_info enum_respanswer  \
# 0                NaN  ...            3          1               1
# 1        2369.813676  ...            2          1               0
# 2        2350.420408  ...            4          1               0
# 3        2522.103025  ...            4          1               1
# 4                NaN  ...            3          1               0
#
#    enum_rightresp                                         open_notes  \
# 0               1                                                NaN
# 1               0  It was good, but I do believe some smaller adj...
# 2               1  The survey is well categorized, easy to collec...
# 3               1                                            Alright
# 4               1                                                NaN
#
#                                   instanceID formdef_version review_quality  \
# 0  uuid:b083aac4-40ea-4ba3-8d67-28c18756c286      2110311300            NaN
# 1  uuid:ee4e1b20-b5d8-41fb-8be3-9595768ccedf      2110311300            NaN
# 2  uuid:ac23afbc-4643-408f-b81c-dc8b6d7cb8e4      2110311300            NaN
# 3  uuid:cc607079-851b-40da-8cc1-b6084407236a      2110311300            NaN
# 4  uuid:7367d47b-fb2d-465a-b455-e9c1c077117d      2110311300            NaN
#
#   review_status                                        KEY
# 0      APPROVED  uuid:b083aac4-40ea-4ba3-8d67-28c18756c286
# 1      APPROVED  uuid:ee4e1b20-b5d8-41fb-8be3-9595768ccedf
# 2      APPROVED  uuid:ac23afbc-4643-408f-b81c-dc8b6d7cb8e4
# 3      APPROVED  uuid:cc607079-851b-40da-8cc1-b6084407236a
# 4      APPROVED  uuid:7367d47b-fb2d-465a-b455-e9c1c077117d
#
# [5 rows x 451 columns]

# %%
# Identify cells with NA
df.isna().sum()
# Out:
# SubmissionDate       0
# starttime            0
# endtime              0
# deviceid             0
# subscriberid       138
#                   ...
# instanceID           0
# formdef_version      0
# review_quality     138
# review_status        0
# KEY                  0
# Length: 451, dtype: int64

# %%
# Identify test and non-consent survey

#mask_test = np.column_stack([df[col].astype(str).str.contains("TEST|Test", regex=True, na=False) for col in df])

#df_test = df.loc[(mask_test.any(axis=1))]
#df_noconsent = df[df.consent == 0]
#to_be_dropped = pd.concat([df_test, df_noconsent]).index
#df.drop(df.index[to_be_dropped], inplace = True)

#df_test
#df_noconsent

# %%
#Re-arrange so index start from 1, not 0
#df = df.loc[~df.index.isin(to_be_dropped)]
df.index = np.arange(1,len(df)+1)
df
# Out:
#               SubmissionDate                 starttime  \
# 1     Nov 8, 2021 5:19:49 PM    Nov 8, 2021 5:18:43 PM
# 2    Nov 10, 2021 9:08:52 PM   Nov 10, 2021 8:36:42 PM
# 3    Nov 13, 2021 4:13:39 AM  Nov 11, 2021 10:15:07 AM
# 4    Nov 13, 2021 4:15:40 AM   Nov 12, 2021 3:12:34 PM
# 5    Nov 13, 2021 7:06:23 AM   Nov 12, 2021 5:08:34 PM
# ..                       ...                       ...
# 134   Mar 6, 2022 8:22:32 AM    Mar 6, 2022 4:58:59 AM
# 135   Mar 6, 2022 8:22:33 AM    Mar 6, 2022 6:18:38 AM
# 136   Mar 6, 2022 8:22:33 AM    Mar 6, 2022 6:43:02 AM
# 137   Mar 6, 2022 8:22:34 AM    Mar 6, 2022 7:18:06 AM
# 138   Mar 6, 2022 8:22:35 AM    Mar 6, 2022 7:48:21 AM
#
#                       endtime                              deviceid  \
# 1      Nov 8, 2021 5:19:49 PM                                 (web)
# 2     Nov 10, 2021 9:08:29 PM                      712fced929bac385
# 3    Nov 11, 2021 10:52:51 AM  6BE46C2F-58A9-4B7A-A482-09B951A157AF
# 4     Nov 12, 2021 3:24:51 PM  6BE46C2F-58A9-4B7A-A482-09B951A157AF
# 5    Nov 13, 2021 12:43:14 AM                      cc93a8f522482023
# ..                        ...                                   ...
# 134    Mar 6, 2022 5:21:12 AM                      cc93a8f522482023
# 135    Mar 6, 2022 6:41:36 AM                      cc93a8f522482023
# 136    Mar 6, 2022 7:16:47 AM                      cc93a8f522482023
# 137    Mar 6, 2022 7:47:00 AM                      cc93a8f522482023
# 138    Mar 6, 2022 8:09:40 AM                      cc93a8f522482023
#
#      subscriberid  simid  devicephonenum  location-Latitude  \
# 1             NaN    NaN             NaN                NaN
# 2             NaN    NaN             NaN           9.017858
# 3             NaN    NaN             NaN           9.005792
# 4             NaN    NaN             NaN           9.046247
# 5             NaN    NaN             NaN                NaN
# ..            ...    ...             ...                ...
# 134           NaN    NaN             NaN                NaN
# 135           NaN    NaN             NaN                NaN
# 136           NaN    NaN             NaN                NaN
# 137           NaN    NaN             NaN                NaN
# 138           NaN    NaN             NaN                NaN
#
#      location-Longitude  location-Altitude  ...  rate_resp_k  enum_info  \
# 1                   NaN                NaN  ...            3          1
# 2             38.834905        2369.813676  ...            2          1
# 3             38.788673        2350.420408  ...            4          1
# 4             38.731529        2522.103025  ...            4          1
# 5                   NaN                NaN  ...            3          1
# ..                  ...                ...  ...          ...        ...
# 134                 NaN                NaN  ...            4          1
# 135                 NaN                NaN  ...            4          1
# 136                 NaN                NaN  ...            4          1
# 137                 NaN                NaN  ...            4          1
# 138                 NaN                NaN  ...            4          1
#
#     enum_respanswer  enum_rightresp  \
# 1                 1               1
# 2                 0               0
# 3                 0               1
# 4                 1               1
# 5                 0               1
# ..              ...             ...
# 134               0               1
# 135               1               1
# 136               0               1
# 137               0               1
# 138               0               1
#
#                                             open_notes  \
# 1                                                  NaN
# 2    It was good, but I do believe some smaller adj...
# 3    The survey is well categorized, easy to collec...
# 4                                              Alright
# 5                                                  NaN
# ..                                                 ...
# 134  This retailer does not need interest bearing l...
# 135                                                NaN
# 136                                                NaN
# 137                                                NaN
# 138                                                NaN
#
#                                     instanceID formdef_version review_quality  \
# 1    uuid:b083aac4-40ea-4ba3-8d67-28c18756c286      2110311300            NaN
# 2    uuid:ee4e1b20-b5d8-41fb-8be3-9595768ccedf      2110311300            NaN
# 3    uuid:ac23afbc-4643-408f-b81c-dc8b6d7cb8e4      2110311300            NaN
# 4    uuid:cc607079-851b-40da-8cc1-b6084407236a      2110311300            NaN
# 5    uuid:7367d47b-fb2d-465a-b455-e9c1c077117d      2110311300            NaN
# ..                                         ...             ...            ...
# 134  uuid:af114ac8-4cee-405a-92dd-f9a6a1294ea0      2202281627            NaN
# 135  uuid:21459ea6-1d15-4358-83c2-e15b0a5f3406      2202281627            NaN
# 136  uuid:5a1ae877-0d7c-4c53-84eb-af13295bf3a9      2202281627            NaN
# 137  uuid:318271b3-1ea1-48b6-8444-f354420a8d8b      2202281627            NaN
# 138  uuid:1bf22d1b-1c7a-494a-8401-2450d1837f45      2202281627            NaN
#
#     review_status                                        KEY
# 1        APPROVED  uuid:b083aac4-40ea-4ba3-8d67-28c18756c286
# 2        APPROVED  uuid:ee4e1b20-b5d8-41fb-8be3-9595768ccedf
# 3        APPROVED  uuid:ac23afbc-4643-408f-b81c-dc8b6d7cb8e4
# 4        APPROVED  uuid:cc607079-851b-40da-8cc1-b6084407236a
# 5        APPROVED  uuid:7367d47b-fb2d-465a-b455-e9c1c077117d
# ..            ...                                        ...
# 134      APPROVED  uuid:af114ac8-4cee-405a-92dd-f9a6a1294ea0
# 135      APPROVED  uuid:21459ea6-1d15-4358-83c2-e15b0a5f3406
# 136      APPROVED  uuid:5a1ae877-0d7c-4c53-84eb-af13295bf3a9
# 137      APPROVED  uuid:318271b3-1ea1-48b6-8444-f354420a8d8b
# 138      APPROVED  uuid:1bf22d1b-1c7a-494a-8401-2450d1837f45
#
# [138 rows x 451 columns]

# %%
# print a list of column names
col_list = list(df)
print(col_list)
# Out:
# ['SubmissionDate', 'starttime', 'endtime', 'deviceid', 'subscriberid', 'simid', 'devicephonenum', 'location-Latitude', 'location-Longitude', 'location-Altitude', 'location-Accuracy', 'duration', 'date', 'phase', 'enumerator', 'rtid_key', 'rt_replacement', 'district', 'district97', 'subdistrict', 'subdistrict97', 'consent', 'resp_name_pl', 'resp_sex_pl', 'resp_mobilenum_pl', 'resp_position_pl', 'businessname_pl', 'countrycurrency_pl', 'country_pl', 'admin1_pl', 'admin2_pl', 'assessor_pl', 'assessorcontact_pl', 'client_pl', 'currentyear', 'rt_position', 'rt_position97', 'phonenumber', 'rgender', 'literacy', 'primaryyear', 'a2f', 'businessyears', 'cs_shops', 'storecount_count', 'decisiongender_1', 'servinggender_1', 'decisiongender_2', 'servinggender_2', 'decisiongender_3', 'servinggender_3', 'decisiongender_4', 'servinggender_4', 'cs_employee', 'cs_womenempl', 'maleemployee', 'cs_femployee', 'paidemployee', 'cs_wfemployee', 'mfemployee', 'cs_emplmanager', 'cs_womenmanager', 'cs_cust', 'cs_wucust', 'cs_loyal', 'cs_credit', 'cs_credit_type', 'cs_credit_type_1', 'cs_credit_type_2', 'cs_credit_type_97', 'cs_credit97', 'pts_records', 'pts_records1', 'pts_records2', 'pts_records3', 'pts_records4', 'pts_records5', 'pts_records_image_proof', 'businessname', 'pts_bk', 'pts_bk_how', 'pts_ledger', 'pts_ledger_cash', 'pts_ledger_sales', 'pts_ledger_expense', 'pts_ledger_asset', 'pts_ledger_inv', 'pts_ledger_credit', 'pts_payable', 'pts_ledger_other', 'pts_ledgerother', 'pts_fs', 'pts_fs_cash', 'pts_fs_pl', 'pts_fs_bs', 'pts_fs_other', 'pts_fsother', 'pts_fs_prep', 'pts_fs_prep97', 'pts_fsreview', 'fsreview_question', 'review_yes', 'review_97', 'pts_fsreview97', 'tdiapps', 'app_as', 'app_its', 'app_pos', 'app_ccpayment', 'app_ict_s', 'app_ict_c', 'app_97', 'tdiapps97', 'pp_goals', 'pp_ap', 'pp_written', 'pp_ap_written_image', 'pp_ap_budget', 'rm_insurance', 'rm_question', 'rm_p_insurance', 'rm_v_insurance', 'rm_l_insurance', 'rm_h_insurance', 'rm_storage', 'rm_97_insurance', 'rm_writtencash', 'rm_writteninvent', 'rm_locked', 'rm_security', 'rm_safe', 'rm_budget', 'rm_inventory', 'rm_cash', 'rm_reserves', 'rm_succession', 'rm_insurance97', 'pts_ledger_update', 'pts_ledger_update97', 'pts_inventory', 'pts_inventory97', 'ee_reg', 'ee_training', 'ee_trainers', 'ee_trainers_1', 'ee_trainers_2', 'ee_trainers_3', 'ee_trainers_4', 'ee_trainers_5', 'ee_trainers_97', 'ee_trainers97', 'ee_groups', 'ee_otherbusiness', 'otherbusiness', 'ofp_lasset', 'ofp_lasset_bldng', 'ofp_lasset_bldng_num', 'ofp_lasset_shed', 'ofp_lasset_shed_num', 'lstorage_num_count', 'lsize_know_1', 'Size_lease_1', 'Measuring_unit_lease_1', 'Other_unit_lease_1', 'lsize_know_2', 'Size_lease_2', 'Measuring_unit_lease_2', 'Other_unit_lease_2', 'lsize_know_3', 'Size_lease_3', 'Measuring_unit_lease_3', 'Other_unit_lease_3', 'ofp_lasset_truck', 'ofp_lasset_truck_num', 'ltrucksize_s', 'cal_ltrucksize_s', 'ltrucksize_m', 'cal_ltrucksize_m', 'ltrucksize_l', 'cal_ltrucksize_l', 'ltrucksize_vl', 'cal_ltrucksize_vl', 'ltrucksize_97', 'cal_ltrucksize_97', 'ltrucksize_idk', 'cal_ltrucksize_idk', 'ltrucksum', 'trucksize97', 'ofp_lasset_motorbike', 'ofp_lasset_motorbike_num', 'ofp_lasset_computer', 'ofp_lasset_computer_num', 'ofp_lasset97', 'ofp_lasset97_item', 'ofp_lasset97_num', 'ofp_asset_bldng', 'ofp_asset_bldng_num', 'ofp_asset_shed', 'ofp_asset_shed_num', 'ostorage_num_count', 'osize_know_1', 'Size_own_1', 'Measuring_unit_own_1', 'Other_unit_own_1', 'osize_know_2', 'Size_own_2', 'Measuring_unit_own_2', 'Other_unit_own_2', 'ofp_asset_truck', 'ofp_asset_truck_num', 'otrucksize_s', 'cal_otrucksize_s', 'otrucksize_m', 'cal_otrucksize_m', 'otrucksize_l', 'cal_otrucksize_l', 'otrucksize_vl', 'cal_otrucksize_vl', 'otrucksize_97', 'cal_otrucksize_97', 'otrucksize_idk', 'cal_otrucksize_idk', 'otrucksum', 'otrucksize97', 'ofp_asset_motorbike', 'ofp_asset_motorbike_num', 'ofp_asset_computer', 'ofp_asset_computer_num', 'ofp_asset97', 'ofp_asset97_item', 'ofp_asset97_num', 'shopsize_question', 'ofp_shopsi ...

# %%
# Add survey metadata to a different df (without review_quality and review_status)
df_meta_df = df[['SubmissionDate','starttime','endtime', 
                 'deviceid','subscriberid','simid','devicephonenum', 
                 'location-Latitude','location-Longitude','location-Altitude', 
                 'location-Accuracy','duration','date','enumerator','a2f', 
                 'rtid_key','rt_replacement', 
                 'rt_position','rt_position97','consent',
                 'businessname_pl','instanceID']].copy()

# %%
# Drop unneccessary columns from main df 
df.drop(['SubmissionDate', 'starttime', 'endtime', 'deviceid', 
         'subscriberid', 'simid', 'devicephonenum', 'location-Latitude',
         'location-Longitude', 'location-Altitude', 'location-Accuracy',
         'instanceID', 'formdef_version', 'KEY'], 
        axis = 1, inplace = True)

# %%
# Convert duration variable from seconds to minutes
df['duration_min'] = df['duration']/60
df.drop(['duration'], axis = 1, inplace = True)

# %%
# ## Answer Scores & Weighted Question Scores

# %%
# ### Customer Service `cs_`

# %%
cs_cols = ['cs_shops', 'cs_employee', 'cs_emplmanager', 'cs_womenempl', 
           'cs_womenmanager', 'cs_cust', 'cs_wucust', 'cs_loyal', 'cs_credit', 
           'cs_credit_type', 'cs_credit_type_1', 'cs_credit_type_2', 'cs_credit_type_97', 
           'cs_credit97']

df[cs_cols].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 138 entries, 1 to 138
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   cs_shops           134 non-null    float64
#  1   cs_employee        134 non-null    float64
#  2   cs_emplmanager     134 non-null    float64
#  3   cs_womenempl       134 non-null    float64
#  4   cs_womenmanager    134 non-null    float64
#  5   cs_cust            134 non-null    float64
#  6   cs_wucust          134 non-null    float64
#  7   cs_loyal           134 non-null    float64
#  8   cs_credit          134 non-null    float64
#  9   cs_credit_type     105 non-null    object
#  10  cs_credit_type_1   105 non-null    float64
#  11  cs_credit_type_2   105 non-null    float64
#  12  cs_credit_type_97  105 non-null    float64
#  13  cs_credit97        3 non-null      object
# dtypes: float64(12), object(2)
# memory usage: 16.2+ KB

# %%
# #### Answer Scores (unweighted)

# %%
# number of shops: 100 if more than 1
df['cs_shops_sc'] = np.where(df['cs_shops'] > 1, 100, 0)

# %%
# loyal customers percentage who buy 50%+ of their product from the retailer's shop 
df['cs_cust_loyal_perc'] = ((df['cs_loyal']/df['cs_cust'])*100).round(1)
df['cs_cust_loyal_sc'] = df['cs_cust_loyal_perc'].round(0)

# %%
# Does the Retail Business offer credit to customers?
df['cs_credit_sc'] = np.where(df['cs_credit'] == 1, 100, 0)

# %%
# #### Weighted Question/Variables Score

# %%
# Apply the question weights to each score answer variable
df['cs_shops_scw'] = df['cs_shops_sc'] * 0.10
df['cs_cust_loyal_scw'] = df['cs_cust_loyal_sc'] * 0.60
df['cs_credit_scw'] = df['cs_credit_sc'] * 0.30

cs_scw_vars = ['cs_shops_scw', 'cs_cust_loyal_scw', 'cs_credit_scw']

# %%
# ### Performance Tracking Systems and Technology/Digital Integrations `pts_` and 'tdiapps_'

# %%
pts_cols = ['pts_records', 'pts_records1', 'pts_records2', 'pts_records3', 
            'pts_records4', 'pts_records5',  
            'pts_records_image_proof', 'pts_bk', 'pts_bk_how', 'pts_ledger', 
            'pts_ledger_cash', 'pts_ledger_sales', 'pts_ledger_expense', 'pts_ledger_asset', 
            'pts_ledger_inv', 'pts_ledger_credit', 'pts_payable', 'pts_ledger_other', 'pts_ledgerother', 
            'pts_fs', 'pts_fs_cash', 'pts_fs_pl', 'pts_fs_bs', 'pts_fs_other', 
            'pts_fsother', 'pts_fs_prep', 'pts_fs_prep97', 'pts_fsreview', 'fsreview_question', 
            'review_yes', 'review_97', 'pts_fsreview97', 'tdiapps', 'app_as', 
            'app_its', 'app_pos', 'app_ccpayment', 'app_ict_s', 'app_ict_c', 'app_97', 
            'tdiapps97', 'pts_ledger_update', 'pts_ledger_update97', 'pts_inventory','pts_inventory97']

df[pts_cols].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 138 entries, 1 to 138
# Data columns (total 45 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   pts_records              0 non-null      float64
#  1   pts_records1             134 non-null    float64
#  2   pts_records2             134 non-null    float64
#  3   pts_records3             134 non-null    float64
#  4   pts_records4             134 non-null    float64
#  5   pts_records5             134 non-null    float64
#  6   pts_records_image_proof  50 non-null     object
#  7   pts_bk                   134 non-null    float64
#  8   pts_bk_how               94 non-null     float64
#  9   pts_ledger               0 non-null      float64
#  10  pts_ledger_cash          134 non-null    float64
#  11  pts_ledger_sales         134 non-null    float64
#  12  pts_ledger_expense       134 non-null    float64
#  13  pts_ledger_asset         134 non-null    float64
#  14  pts_ledger_inv           134 non-null    float64
#  15  pts_ledger_credit        105 non-null    float64
#  16  pts_payable              134 non-null    float64
#  17  pts_ledger_other         134 non-null    float64
#  18  pts_ledgerother          3 non-null      object
#  19  pts_fs                   0 non-null      float64
#  20  pts_fs_cash              70 non-null     float64
#  21  pts_fs_pl                134 non-null    float64
#  22  pts_fs_bs                134 non-null    float64
#  23  pts_fs_other             134 non-null    float64
#  24  pts_fsother              4 non-null      object
#  25  pts_fs_prep              113 non-null    float64
#  26  pts_fs_prep97            6 non-null      object
#  27  pts_fsreview             134 non-null    float64
#  28  fsreview_question        0 non-null      float64
#  29  review_yes               37 non-null     float64
#  30  review_97                37 non-null     float64
#  31  pts_fsreview97           4 non-null      object
#  32  tdiapps                  0 non-null      float64
#  33  app_as                   134 non-null    float64
#  34  app_its                  134 non-null    float64
#  35  app_pos                  134 non-null    float64
#  36  app_ccpayment            134 non-null    float64
#  37  app_ict_s                134 non-null    float64
#  38  app_ict_c                134 non-null    float64
#  39  app_97                   134 non-null    float64
#  40  tdiapps97                2 non-null      object
#  41  pts_ledger_update        21 non-null     float64
#  42  pts_ledger_update97      1 non-null      object
#  43  pts_inventory            38 non-null     float64
#  44  pts_inventory97          5 non-null      object
# dtypes: float64(37), object(8)
# memory usage: 49.6+ KB

# %%
# Which of the following <b>records</b> does the Retail Business have?
df['pts_records_sc'] = (df['pts_records1']*20 
                        + df['pts_records2']*20 
                        + df['pts_records3']*10 
                        + df['pts_records4']*25 
                        + df['pts_records5']*25)

# %%
# Does the Retail Business do bookkeeping?
df['pts_bk_sc'] = np.where(df['pts_bk'] == 1, 100, 0)

# %%
# How does the Retail Business do bookkeeping?
df['pts_bk_how_sc'] = np.where(df['pts_bk_how'] == 1, 50, 
                               np.where(df['pts_bk_how'] == 2, 100, 0))

# %%
#fake variables (to be changed)
#df['pts_ledger_payables'] = df['pts_ledger_credit']

# What business activities does the Retail Business document?
df['pts_ledger_sc'] = (df['pts_ledger_cash']*10 
                       + df['pts_ledger_sales']*15 
                       + df['pts_ledger_expense']*15 
                       + df['pts_ledger_asset']*15 
                       + df['pts_ledger_inv']*15
                       + df['pts_payable']*15 
                       + df['pts_ledger_credit']*15  
                       + df['pts_ledger_other']*0)

# %%
# How frequently does the Retail Business update the cash record?
df['pts_ledger_update_sc'] = np.where(df['pts_ledger_update'] == 1, 100, 
                                      np.where(df['pts_ledger_update'] == 2, 25,0))

# %%
# How frequently does the Retail Business reconcile inventory?
df['pts_inventory_sc'] = np.where(df['pts_inventory'] == 1, 100,
                                   np.where(['pts_inventory'] == 2, 75,
                                            np.where(['pts_inventory'] == 3, 25, 0)))

# %%
# Which of the following financial statements does the Retail Business prepare?
df['pts_fs_sc'] = (df['pts_fs_cash']*35 
                       + df['pts_fs_pl']*35 
                       + df['pts_fs_bs']*30)

# %%
# Frequency of updates to financial statements not scored

# %%
# Are financial statements audited or reviewed by the following:?
df['pts_fsreview_sc'] = np.where((df['review_yes'] == 1) & (df['review_97'] == 1), 100,
                                   np.where((df['review_yes'] == 1) & (df['review_97'] == 0), 65,
                                     np.where((df['review_yes'] == 0) & (df['review_97'] == 1), 35, 0)))

# %%
# Does the Retail Business use any of the following technology applications?
df['pts_tdiapps_sc'] = (df['app_as']*20 
                        + df['app_its']*20 
                        + df['app_pos']*15 
                        + df['app_ccpayment']*15
                        + df['app_ict_s']*15
                        + df['app_ict_c']*15)

# %%
# #### Weighted Question/Variables Score

# %%
# Apply the question weights to each scored answer variable
df['pts_records_scw'] = df['pts_records_sc']*0.15
df['pts_bk_scw'] = df['pts_bk_sc']*0.10
df['pts_bk_how_scw'] = df['pts_bk_how_sc']*0
df['pts_ledger_scw'] = df['pts_ledger_sc']*0.20
df['pts_ledger_update_scw'] = df['pts_ledger_update_sc']*0.15
df['pts_inventory_scw'] = df['pts_inventory_sc']*0.15
df['pts_fs_scw'] = df['pts_fs_sc']*0.10
df['pts_fsreview_scw'] = df['pts_fsreview_sc']*0.10
df['pts_tdiapps_scw'] = df['pts_tdiapps_sc']*0.05

pts_scw_vars = ['pts_records_scw', 'pts_bk_scw', 'pts_bk_how_scw', 
                'pts_ledger_scw', 'pts_ledger_update_scw', 'pts_inventory_scw', 
                'pts_fs_scw', 'pts_fsreview_scw', 'pts_tdiapps_scw']

# %%
# ### Planning Pratices `pp_`

# %%
pp_cols = ['pp_goals', 'pp_ap', 'pp_written', 'pp_ap_written_image', 'pp_ap_budget']

df[pp_cols].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 138 entries, 1 to 138
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   pp_goals             134 non-null    float64
#  1   pp_ap                54 non-null     float64
#  2   pp_written           37 non-null     float64
#  3   pp_ap_written_image  7 non-null      object
#  4   pp_ap_budget         37 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 6.5+ KB

# %%
# Does the Retailer have goals for the business?
df['pp_goals_sc'] = np.where(df['pp_goals'] == 1, 100, 0)

# %%
# Does the Retailer have a plan for achieving those goals?
df['pp_ap_sc'] = np.where(df['pp_ap'] == 1, 100, 0)

# %%
# Is the plan a written plan?
df['pp_written_sc'] = np.where(df['pp_written'] == 1, 100, 0)

# %%
# Does the plan include a budget?
df['pp_ap_budget_sc'] = np.where(df['pp_ap_budget'] == 1, 100, 0)

# %%
# #### Weighted Question/Variables Score

# %%
# Apply the question weights to each scored answer variable
df['pp_goals_scw'] = df['pp_goals_sc']*0.25
df['pp_ap_scw'] = df['pp_ap_sc']*0.25
df['pp_written_scw'] = df['pp_written_sc']*0.25
df['pp_ap_budget_scw'] = df['pp_ap_budget_sc']*0.25

pp_scw_vars = ['pp_goals_scw', 'pp_ap_scw', 'pp_written_scw', 'pp_ap_budget_scw']

# %%
# ### Risk Management & External Engagement `rmee_`

# %%
rmee_cols = ['rm_insurance', 'rm_question', 'rm_p_insurance', 'rm_v_insurance', 
           'rm_l_insurance', 'rm_h_insurance', 'rm_storage', 'rm_97_insurance', 
           'rm_writtencash', 'rm_writteninvent', 'rm_locked', 'rm_security', 
           'rm_safe', 'rm_budget', 'rm_inventory', 'rm_cash', 'rm_reserves', 
           'rm_succession', 'rm_insurance97', 'ee_reg', 'ee_training', 
           'ee_trainers', 'ee_trainers_1', 'ee_trainers_2', 'ee_trainers_3', 
           'ee_trainers_4', 'ee_trainers_5', 'ee_trainers_97', 'ee_trainers97', 
           'ee_groups', 'ee_otherbusiness']

df[rmee_cols].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 138 entries, 1 to 138
# Data columns (total 31 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   rm_insurance      134 non-null    float64
#  1   rm_question       0 non-null      float64
#  2   rm_p_insurance    5 non-null      float64
#  3   rm_v_insurance    5 non-null      float64
#  4   rm_l_insurance    5 non-null      float64
#  5   rm_h_insurance    5 non-null      float64
#  6   rm_storage        5 non-null      float64
#  7   rm_97_insurance   5 non-null      float64
#  8   rm_writtencash    50 non-null     float64
#  9   rm_writteninvent  59 non-null     float64
#  10  rm_locked         134 non-null    float64
#  11  rm_security       134 non-null    float64
#  12  rm_safe           134 non-null    float64
#  13  rm_budget         134 non-null    float64
#  14  rm_inventory      59 non-null     float64
#  15  rm_cash           70 non-null     float64
#  16  rm_reserves       134 non-null    float64
#  17  rm_succession     134 non-null    float64
#  18  rm_insurance97    3 non-null      object
#  19  ee_reg            134 non-null    float64
#  20  ee_training       134 non-null    float64
#  21  ee_trainers       92 non-null     object
#  22  ee_trainers_1     92 non-null     float64
#  23  ee_trainers_2     92 non-null     float64
#  24  ee_trainers_3     92 non-null     float64
#  25  ee_trainers_4     92 non-null     float64
#  26  ee_trainers_5     92 non-null     float64
#  27  ee_trainers_97    92 non-null     float64
#  28  ee_trainers97     3 non-null      object
#  29  ee_groups         134 non-null    float64
#  30  ee_otherbusiness  134 non-null    float64
# dtypes: float64(28), object(3)
# memory usage: 34.5+ KB

# %%
# Does the Retail Business have insurance?
df['rmee_insurance_sc'] = np.where(df['rm_insurance'] == 1, 100, 0)

# %%
# Which of the following risk mgmt practices does the Retailer use?
df['rmee_sc'] = (df['rm_p_insurance']*0
                 + df['rm_v_insurance']*0 
                 + df['rm_l_insurance']*0
                 + df['rm_h_insurance']*0
                 + df['rm_storage']*5 
                 + df['rm_97_insurance']*0
                 + df['rm_writtencash']*5 
                 + df['rm_writteninvent']*5 
                 + df['rm_locked']*5 
                 + df['rm_security']*5 
                 + df['rm_safe']*5 
                 + df['rm_budget']*10 
                 + df['rm_inventory']*15 
                 + df['rm_cash']*15
                 + df['rm_reserves']*15 
                 + df['rm_succession']*15)

# %%
# Is the Retail Business officially registered?
df['rmee_reg_sc'] = np.where(df['ee_reg'] == 1, 100, 0)

# %%
# Has the Respondent participated in training programs related to the Retail Business 
#  in the past 3 years?
df['rmee_training_sc'] = np.where(df['ee_training'] == 1, 100, 0)

# %%
# Does the Respondent belong to any professional organizations or groups related to 
#  his/her farming activity and/or to the Retail Business?
df['rmee_groups_sc'] = np.where(df['ee_groups'] == 1, 100, 0)

# %%
# Does the Retailer own or operate another enterprise or business in addition to the Retail Business?
df['rmee_otherbusiness_sc'] = np.where(df['ee_otherbusiness'] == 1, 100, 0)

# %%
# #### Weighted Question/Variable Score

# %%
# Apply the question weights to each scored answer variable
df['rmee_insurance_scw'] = df['rmee_insurance_sc']*0.1
df['rmee_scw'] = df['rmee_sc']*0.50
df['rmee_reg_scw'] = df['rmee_reg_sc']*0.15
df['rmee_training_scw'] = df['rmee_training_sc']*0.05
df['rmee_groups_scw'] = df['rmee_groups_sc']*0.05
df['rmee_otherbusiness_scw'] = df['rmee_otherbusiness_sc']*0.15

rmee_scw_vars = ['rmee_insurance_scw', 'rmee_scw', 'rmee_reg_scw', 
                 'rmee_training_scw', 'rmee_groups_scw', 'rmee_otherbusiness_scw']

# %%
# ### Operational & Financial Performance `ofp_`

# %%
ofp_cols = ['ofp_lasset', 'ofp_lasset_bldng', 'ofp_lasset_bldng_num', 'ofp_lasset_shed', 
            'ofp_lasset_shed_num', 'lstorage_num_count', 'ofp_lasset_truck', 
            'ofp_lasset_truck_num', 'ltrucksize_s', 'cal_ltrucksize_s', 
            'ltrucksize_m', 'cal_ltrucksize_m', 'ltrucksize_l', 'cal_ltrucksize_l', 
            'ltrucksize_vl', 'cal_ltrucksize_vl', 'ltrucksize_97', 'cal_ltrucksize_97',
            'ltrucksize_idk', 'cal_ltrucksize_idk', 'ltrucksum', 'trucksize97', 
            'ofp_lasset_motorbike', 'ofp_lasset_motorbike_num', 'ofp_lasset_computer', 
            'ofp_lasset_computer_num', 'ofp_lasset97', 'ofp_lasset97_item', 
            'ofp_lasset97_num', 'ofp_asset_bldng', 'ofp_asset_bldng_num', 'ofp_asset_shed', 
            'ofp_asset_shed_num', 'ostorage_num_count', 'osize_know_1', 'Size_own_1', 
            'Measuring_unit_own_1', 'Other_unit_own_1', 'ofp_asset_truck', 
            'ofp_asset_truck_num', 'otrucksize_s', 'cal_otrucksize_s', 'otrucksize_m', 
            'cal_otrucksize_m', 'otrucksize_l', 'cal_otrucksize_l', 'otrucksize_vl', 
            'cal_otrucksize_vl', 'otrucksize_97', 'cal_otrucksize_97', 'otrucksize_idk', 
            'cal_otrucksize_idk', 'otrucksum', 'otrucksize97', 'ofp_asset_motorbike', 
            'ofp_asset_motorbike_num', 'ofp_asset_computer', 'ofp_asset_computer_num', 
            'ofp_asset97', 'ofp_asset97_item', 'ofp_asset97_num', 'shopsize_question', 
            'ofp_shopsize', 'ofp_shopsizeunit', 'ofp_shopsizeunit97', 'nearestyear_cal', 
            'middleyear_cal', 'furtherstyear_cal', 'yeardif', 'valuesale_question', 
            'vs_nearestyear', 'vs_middleyear', 'vs_furtherstyear', 'ofp_valuenearestyear', 
            'ofp_valuemiddleyear', 'ofp_valuefurthestyear', 'profit_question', 
            'p_nearestyear', 'p_middleyear', 'p_furtherstyear', 'ofp_profitnearestyear', 
            'ofp_profitmiddleyear', 'ofp_profitfurthestyear', 'monthlyexp_question', 
            'ofp_monthlyexp', 'cash_amnt_question', 'ofp_cash_amnt', 'ofp_acct', 
            'ofp_bankacct', 'ofp_borrowed']

df[ofp_cols].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 138 entries, 1 to 138
# Data columns (total 90 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ofp_lasset                134 non-null    float64
#  1   ofp_lasset_bldng          79 non-null     float64
#  2   ofp_lasset_bldng_num      49 non-null     float64
#  3   ofp_lasset_shed           79 non-null     float64
#  4   ofp_lasset_shed_num       62 non-null     float64
#  5   lstorage_num_count        62 non-null     float64
#  6   ofp_lasset_truck          79 non-null     float64
#  7   ofp_lasset_truck_num      8 non-null      float64
#  8   ltrucksize_s              2 non-null      float64
#  9   cal_ltrucksize_s          7 non-null      float64
#  10  ltrucksize_m              3 non-null      float64
#  11  cal_ltrucksize_m          7 non-null      float64
#  12  ltrucksize_l              2 non-null      float64
#  13  cal_ltrucksize_l          7 non-null      float64
#  14  ltrucksize_vl             3 non-null      float64
#  15  cal_ltrucksize_vl         7 non-null      float64
#  16  ltrucksize_97             2 non-null      float64
#  17  cal_ltrucksize_97         7 non-null      float64
#  18  ltrucksize_idk            3 non-null      float64
#  19  cal_ltrucksize_idk        7 non-null      float64
#  20  ltrucksum                 7 non-null      float64
#  21  trucksize97               2 non-null      object
#  22  ofp_lasset_motorbike      79 non-null     float64
#  23  ofp_lasset_motorbike_num  10 non-null     float64
#  24  ofp_lasset_computer       79 non-null     float64
#  25  ofp_lasset_computer_num   10 non-null     float64
#  26  ofp_lasset97              79 non-null     float64
#  27  ofp_lasset97_item         6 non-null      object
#  28  ofp_lasset97_num          6 non-null      float64
#  29  ofp_asset_bldng           134 non-null    float64
#  30  ofp_asset_bldng_num       50 non-null     float64
#  31  ofp_asset_shed            134 non-null    float64
#  32  ofp_asset_shed_num        62 non-null     float64
#  33  ostorage_num_count        62 non-null     float64
#  34  osize_know_1              49 non-null     float64
#  35  Size_own_1                45 non-null     float64
#  36  Measuring_unit_own_1      45 non-null     float64
#  37  Other_unit_own_1          0 non-null      float64
#  38  ofp_asset_truck           134 non-null    float64
#  39  ofp_asset_truck_num       17 non-null     float64
#  40  otrucksize_s              5 non-null      float64
#  41  cal_otrucksize_s          14 non-null     float64
#  42  otrucksize_m              3 non-null      float64
#  43  cal_otrucksize_m          14 non-null     float64
#  44  otrucksize_l              1 non-null      float64
#  45  cal_otrucksize_l          14 non-null     float64
#  46  otrucksize_vl             3 non-null      float64
#  47  cal_otrucksize_vl         14 non-null     float64
#  48  otrucksize_97             1 non-null      float64
#  49  cal_otrucksize_97         14 non-null     float64
#  50  otrucksize_idk            2 non-null      float64
#  51  cal_otrucksize_idk        14 non-null     float64
#  52  otrucksum                 14 non-null     float64
#  53  otrucksize97              1 non-null      object
#  54  ofp_asset_motorbike       134 non-null    float64
#  55  ofp_asset_motorbike_num   21 non-null     float64
#  56  ofp_asset_computer        134 non-null    float64
#  57  ofp_asset_computer_num    27 non-null     float64
#  58  ofp_asset97               134 non-null    float64
#  59  ofp_asset97_item          12 non-null     object
#  60  ofp_asset97_num           12 non-null     float64
#  61  shopsize_question         134 non-null    float64
#  62  ofp_shopsize              124 non-null    float64
#  63  ofp_shopsizeunit          124 non-null    float64
#  64  ofp_shopsizeunit97        0 non-null      float64
#  65  nearestyear_cal           134 non-null    float64
#  66  middleyear_cal            134 non-null    float64
#  67  furtherstyear_cal         134 non-null    float64
#  68  yeardif                   134 non-null    float64
#  69  valuesale_question        0 non-null      float64
#  70  vs_nearestyear            134 non-null    float64
#  71  vs_middleyear             124 non-null    float64
#  72  vs_furtherstyear          101 non-null    float64
#  73  ofp_valuenearestyear      101 non-null    float64
#  74  ofp_valuemiddleyear       92 non-null     float64
#  75  ofp_valuefurthestyear     74 non-null     float64
#  76  profit_question           0 non-null      float64
#  77  p_nearestyear             134 non-null    float64
#  78  p_middleyear              124 non-null    float64
#  79  p_furtherstyear           101 non-null    float64
#  80  ofp_profitnearestyear     89 non-null     float64
#  81  ofp_profitmiddleyear      81 non-null     float64
#  82  ofp_profitfurthestyear    65 non-null     float64
#  83  monthlyexp_question       134 non-null    float64
#  84  ofp_monthlyexp            116 non-null    float64
#  85  cash_amnt_question        68 non-null     float64
#  86  ofp_cash_amnt             60 non-null     float64
#  87  ofp_acct                  134 non-null    float64
#  88  ofp_bankacct              59 non-null     float64
#  89  ofp_borrowed              134 non-null    float64
# dtypes: float64(86), object(4)
# memory usage: 98.1+ KB

# %%
# Does the Retailer keep business accounts separate from other accounts?
df['ofp_acct_sc'] = np.where(df['ofp_acct'] == 1, 100, 0)

# %%
# Does the Retailer earn a margin or a commission on business activities?
#df['ofp_margin_sc'] = np.where(df['ofp_margin'] == 1, 100, 0)

# %%
# Does the Retailer have a bank account?
df['ofp_bankacct_sc'] = np.where(df['ofp_bankacct'] == 1, 100, 0)

# %%
# Has the Retailer obtained a loan with the last 3 years from a financial institution?
df['ofp_borrowed_sc'] = np.where(df['ofp_borrowed'] == 1, 100, 0)

# %%
# #### Weighted Question/Variable Score

# %%
# Apply the question weights to each score answer variable
df['ofp_acct_scw'] = df['ofp_acct_sc']*0.25
#df['ofp_margin_scw'] = df['ofp_margin_sc']*0.10
df['ofp_bankacct_scw'] = df['ofp_bankacct_sc']*0.25
df['ofp_borrowed_scw'] = df['ofp_borrowed_sc']*0.50

ofp_scw_vars = ['ofp_acct_scw', 'ofp_margin_scw', 
                'ofp_bankacct_scw', 'ofp_borrowed_scw']

# %%
# ## Category Scores, Benchmarks, Total Score

# %%
# ### New (non-scored) Variables

# %%
# Sales per Customer (recent year only)
df['sales_per_cust2020'] = (df['ofp_valuenearestyear']/df['cs_cust']).round(0)

# %%
# Sales trends
# convert 0 values to NaN
cols = ['ofp_valuenearestyear', 'ofp_valuemiddleyear', 'ofp_valuefurthestyear']
df[cols] = df[cols].replace({0: np.nan})

# Calculate average sales values
df['sales_avg'] = df[cols].mean(axis=1).round(0)

# Count number of years of available sales data
df['sales_data_years'] = df[cols].count(axis=1)

# Calculate percentage change trends across all possible combinations of available data
df['sales_trend_mid_near'] = ((df['ofp_valuenearestyear'] - df['ofp_valuemiddleyear'])
                           /(df['ofp_valuemiddleyear'])).round(3)
df['sales_trend_mid_near'] = df['sales_trend_mid_near'].replace([np.inf, -np.inf], np.nan)
df['sales_trend_far_mid'] = ((df['ofp_valuemiddleyear'] - df['ofp_valuefurthestyear'])
                           /(df['ofp_valuefurthestyear'])).round(3)
df['sales_trend_far_mid'] = df['sales_trend_far_mid'].replace([np.inf, -np.inf], np.nan)
df['sales_trend_far_near'] = ((df['ofp_valuenearestyear'] - df['ofp_valuefurthestyear'])
                           /(df['ofp_valuefurthestyear'])).round(3)
df['sales_trend_far_near'] = df['sales_trend_far_near'].replace([np.inf, -np.inf], np.nan)

# Calculate the average percentage change trend
df['sales_trend_avg'] = df[['sales_trend_far_near', 'sales_trend_far_mid', 
                            'sales_trend_mid_near']].mean(axis=1).round(3)

# Add description for available trend
df['sales_trend_desc'] = np.where(df['sales_trend_avg'] > 0.0, 'Increase',                                   np.where(df['sales_trend_avg'] == 0.0, 'No Change', 
                                           np.where(df['sales_trend_avg'] < 0.0, 
                                                    'Decrease', 
                                                    'Not enough sales data available')))

# %%
# Months of cash reserves
# fill NaNs in cash amount to 0 because if retail doesn't keep cash reserve, 
#  then their amount is 0
df['ofp_cash_amnt'] = df['ofp_cash_amnt'].fillna(0)
df['monthscashreserve'] = (df['ofp_cash_amnt']/df['ofp_monthlyexp']).round(1)

# %%
# ### Weighted Category & Total ALP Scores

# %%
print(cs_scw_vars)
print(pts_scw_vars)
print(pp_scw_vars)
print(rmee_scw_vars)
print(ofp_scw_vars)
# Out:
# ['cs_shops_scw', 'cs_cust_loyal_scw', 'cs_credit_scw']
# ['pts_records_scw', 'pts_bk_scw', 'pts_bk_how_scw', 'pts_ledger_scw', 'pts_ledger_update_scw', 'pts_inventory_scw', 'pts_fs_scw', 'pts_fsreview_scw', 'pts_tdiapps_scw']
# ['pp_goals_scw', 'pp_ap_scw', 'pp_written_scw', 'pp_ap_budget_scw']
# ['rmee_insurance_scw', 'rmee_scw', 'rmee_reg_scw', 'rmee_training_scw', 'rmee_groups_scw', 'rmee_otherbusiness_scw']
# ['ofp_acct_scw', 'ofp_margin_scw', 'ofp_bankacct_scw', 'ofp_borrowed_scw']

# %%
# The weighted category score (sum of weighted question scores times categ weight
df['cs_categ_scw'] = ((df['cs_shops_scw'].fillna(0) 
                       + df['cs_cust_loyal_scw'].fillna(0) 
                       + df['cs_credit_scw'].fillna(0))*0.20).round(0)

df['pts_categ_scw'] = ((df['pts_records_scw'].fillna(0) 
                        + df['pts_bk_scw'].fillna(0) 
                        + df['pts_bk_how_scw'].fillna(0) 
                        + df['pts_ledger_scw'].fillna(0) 
                        + df['pts_ledger_update_scw'].fillna(0) 
                        + df['pts_inventory_scw'].fillna(0) 
                        + df['pts_fs_scw'].fillna(0)
                        + df['pts_fsreview_scw'].fillna(0) 
                        + df['pts_tdiapps_scw'].fillna(0))*0.20).round(0)

df['pp_categ_scw'] = ((df['pp_goals_scw'].fillna(0) 
                       + df['pp_ap_scw'].fillna(0) 
                       + df['pp_written_scw'].fillna(0) 
                       + df['pp_ap_budget_scw'].fillna(0))*0.20).round(0)

df['rmee_categ_scw'] = ((df['rmee_insurance_scw'].fillna(0)
                         + df['rmee_scw'].fillna(0) 
                         + df['rmee_reg_scw'].fillna(0) 
                         + df['rmee_training_scw'].fillna(0) 
                         + df['rmee_groups_scw'].fillna(0) 
                         + df['rmee_otherbusiness_scw'].fillna(0))*0.20).round(0)

df['ofp_categ_scw'] = ((df['ofp_acct_scw'].fillna(0) 
                        #+ df['ofp_margin_scw'].fillna(0) 
                        + df['ofp_bankacct_scw'].fillna(0) 
                        + df['ofp_borrowed_scw'].fillna(0))*0.20).round(0)

# %%
# ### ALP Total Scores

# %%
df['total_sc'] = (df['cs_categ_scw'] 
                  + df['pts_categ_scw'] 
                  + df['pp_categ_scw'] 
                  + df['rmee_categ_scw'] 
                  + df['ofp_categ_scw']).round(0)
df['total_sc']
# Out:
# 1       0.0
# 2      24.0
# 3      64.0
# 4      21.0
# 5      52.0
#        ...
# 134    29.0
# 135    16.0
# 136    24.0
# 137    27.0
# 138    21.0
# Name: total_sc, Length: 138, dtype: float64

# %%
# ### Conditionality Checks - Adjustment to Total Score

# #### Conditionality: Cannot be in green category if:
# - Does not do bookkeeping.
# - Is not officially registered.

# conditionality check - no bookkeeping 
conditions_bk = [(df['total_sc'] <= 66.0),                
                 ((df['total_sc'] >  66.0) & (df['pts_bk'] == 1)),                
                 ((df['total_sc'] >  66.0) & (df['pts_bk'] == 0))]

values_conditions_bk = ['Conditionality check not required', 
                        'Passes conditionality check',                        
                        'FAILS conditionality check - cannot score above 66 because does not do bookkeeping']

df['cc_bk'] = np.select(conditions_bk, values_conditions_bk)

# conditionality check - not legally registered
conditions_reg = [(df['total_sc'] <= 66.0),                 
                  ((df['total_sc'] >  66.0) & (df['ee_reg'] == 1)),                 
                  ((df['total_sc'] >  66.0) & (df['ee_reg'] == 0))]

values_conditions_reg = ['Conditionality check not required', 
                         'Passes conditionality check',                         
                         'FAILS conditionality check - cannot score above 66 because not legally registred']

df['cc_reg'] = np.select(conditions_reg, values_conditions_reg)

# %%
# Generate final score based on adjustments from conditionality check - 
#  if failed conditionalities, drop to 66 (yellow category)
df['total_sc_final'] = np.where((df['cc_bk'] == 'FAILS conditionality check - cannot score above 66 because does not do bookkeeping')|
                                (df['cc_reg'] == 'FAILS conditionality check - cannot score above 66 because not legally registred'), 
                                66.0,                                 
                                df['total_sc'])

total_sc_categ_conditions = [(df['total_sc_final'] <= 33.0),
                             ((df['total_sc_final'] >  33.0) & 
                              (df['total_sc_final'] <= 66.0)),
                             (df['total_sc_final'] >  66.0)]

total_sc_categ_values = ['Red', 'Yellow', 'Green']

df['total_sc_categ'] = np.select(total_sc_categ_conditions, total_sc_categ_values)

df['total_sc_desc'] = np.where(df['total_sc_categ'] == 'Red', 
                               'Very immature, needs basic systems and mgmt practices',
                                 np.where(df['total_sc_categ'] == 'Yellow', 
                                          'Average application of mgmt systems and practices, can improve operational and financial performance',                                          
                                          np.where(df['total_sc_categ'] == 'Green', 
                                                   'Top performer, areas for improvement',0)))

# %%
# ## Benchmarks - Average & Top Quartiles

# %%
# calculate average score per category
df['cs_categ_avg'] = np.round(df['cs_categ_scw'].mean(),0)
df['pts_categ_avg'] = np.round(df['pts_categ_scw'].mean(),0)
df['pp_categ_avg'] = np.round(df['pp_categ_scw'].mean(),0)
df['rmee_categ_avg'] = np.round(df['rmee_categ_scw'].mean(),0)
df['ofp_categ_avg'] = np.round(df['ofp_categ_scw'].mean(),0)
df['total_sc_final_avg'] = np.round(df['total_sc_final'].mean(),0)

# %%
# average benchmark for new vars
df['cs_cust_loyal_perc_avg'] = np.round(df['cs_cust_loyal_perc'].mean(),2)
df['sales_per_cust2020_avg'] = np.round(df['sales_per_cust2020'].mean(),0)
df['monthscashreserve_avg'] = np.round(df['monthscashreserve'].mean(),1)

# %%
# calculate top quartile per category
df['cs_categ_topq'] = df['cs_categ_scw'].quantile(0.75).round(0)
df['pts_categ_topq'] = df['pts_categ_scw'].quantile(0.75).round(0)
df['pp_categ_topq'] = df['pp_categ_scw'].quantile(0.75).round(0)
df['rmee_categ_topq'] = df['rmee_categ_scw'].quantile(0.75).round(0)
df['ofp_categ_topq'] = df['ofp_categ_scw'].quantile(0.75).round(0)
df['total_sc_final_topq'] = df['total_sc_final'].quantile(0.75).round(0)

# %%
# top quantile benchmarks for new vars
df['cs_cust_loyal_perc_topq'] = df['cs_cust_loyal_perc'].quantile(0.75).round(2)
df['sales_per_cust2020_topq'] = df['sales_per_cust2020'].quantile(0.75).round(0)
df['monthscashreserve_topq'] = df['monthscashreserve'].quantile(0.75).round(1)

# %%
# ## Reporting

# %%
df['total_sc_categ'].value_counts()
# Out:
# Red       84
# Yellow    49
# Green      5
# Name: total_sc_categ, dtype: int64

# %%
final_score_cols = ['cs_categ_scw', 'pts_categ_scw', 'pp_categ_scw', 'rmee_categ_scw', 
                    'ofp_categ_scw','total_sc_final']

# %%
df.columns[:35]
# Out:
# Index(['date', 'phase', 'enumerator', 'rtid_key', 'rt_replacement', 'district',
#        'district97', 'subdistrict', 'subdistrict97', 'consent', 'resp_name_pl',
#        'resp_sex_pl', 'resp_mobilenum_pl', 'resp_position_pl',
#        'businessname_pl', 'countrycurrency_pl', 'country_pl', 'admin1_pl',
#        'admin2_pl', 'assessor_pl', 'assessorcontact_pl', 'client_pl',
#        'currentyear', 'rt_position', 'rt_position97', 'phonenumber', 'rgender',
#        'literacy', 'primaryyear', 'a2f', 'businessyears', 'cs_shops',
#        'storecount_count', 'decisiongender_1', 'servinggender_1'],
#       dtype='object')

# %%
# Create dataframe of scores and export
filename = "ALP_Chemtex_FinalScores.xlsx"

df_categ_scores_df = df[final_score_cols]
df_categ_scores_df.describe()
df_categ_scores_df.index = np.arange(1,len(df_categ_scores_df)+1)
df_categ_scores_df.to_excel('./data/processed_data/{}'.format(filename), header = True)
# Out:
#        cs_categ_scw  pts_categ_scw  pp_categ_scw  rmee_categ_scw  \
# count    138.000000     138.000000    138.000000      138.000000
# mean       8.681159       6.246377      5.471014        5.282609
# std        4.057948       3.634409      8.080067        3.139085
# min        0.000000       0.000000      0.000000        0.000000
# 25%        6.250000       3.000000      0.000000        4.000000
# 50%        9.000000       6.000000      0.000000        4.000000
# 75%       11.750000      10.000000     10.000000        7.000000
# max       20.000000      15.000000     20.000000       20.000000
#
#        ofp_categ_scw  total_sc_final
# count     138.000000      138.000000
# mean        7.934783       33.615942
# std         6.692633       17.988773
# min         0.000000        0.000000
# 25%         0.000000       21.250000
# 50%         5.000000       29.500000
# 75%        10.000000       43.500000
# max        20.000000       84.000000

# %%
# ### Apply Label Columns

# %%
# Changes columns' dtypes from int to float
df[['date']].dtypes
columns_int = df.select_dtypes(include=[np.int64, np.int32]).columns
df[columns_int] = df[columns_int].astype(float)
df.info()
# Out:
# date    object
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 138 entries, 1 to 138
# Columns: 526 entries, date to monthscashreserve_topq
# dtypes: float64(447), object(79)
# memory usage: 568.2+ KB

# %%
# Adding new columns with new formulation - revised with Not applicable
import math
df['location'] = df['admin1_pl'].astype(str) + ', ' + df['admin2_pl']
df['pts_inventory_yesno'] = np.where(df['pts_inventory'].isnull(), 'Not applicable', 'YES')


df['cs_cust_rank'] = df['cs_cust'].rank(method = 'first')
df['cs_cust_band'] = pd.qcut(df['cs_cust_rank'], 3, labels = False) + 1

df.fillna({'ofp_lasset_bldng_num':10000,'ofp_lasset_shed_num':10000,'ofp_lasset_truck_num':10000,'ofp_lasset_motorbike_num':10000,\
           'ofp_lasset_computer_num':10000,'ofp_lasset97_num':10000,'ofp_bankacct':10000,\
          }, inplace = True)

df.loc[(df['app_as']+df['app_its']+df['app_pos']+df['app_ccpayment']+df['app_ict_s']+\
        df['app_ict_c']+df['app_97']) >= 1, 'tdiapps_yesno'] = 1
df.loc[df['tdiapps_yesno'].isnull(), 'tdiapps_yesno'] = 0
df.loc[df['tdiapps_yesno'] == 0, 'tdiapps_yesno_label'] = 'NO'
df.loc[df['tdiapps_yesno'] == 1, 'tdiapps_yesno_label'] = 'YES'

df.loc[(df['pts_ledger_cash']+df['pts_ledger_sales']+df['pts_ledger_expense']+df['pts_ledger_asset']+df['pts_ledger_inv']+\
        df['pts_ledger_credit']+df['pts_payable']+df['pts_ledger_other']) >= 1, 'pts_ledger_yesno'] = 1
df.loc[df['pts_ledger_yesno'].isnull(), 'pts_ledger_yesno'] = 0
df.loc[df['pts_ledger_yesno'] == 0, 'pts_ledger_yesno_label'] = 'NO'
df.loc[df['pts_ledger_yesno'] == 1, 'pts_ledger_yesno_label'] = 'YES'

df['pts_ledger_update_yesno'] = np.where((df['pts_ledger_update'] >= 1) & (df['pts_ledger_update'] <= 3), 'YES', 
                                         (np.where(df['pts_ledger_update'] == 0,'NO', 'Not applicable')))

# %%
df.to_csv('./data/processed_data/data_result.csv')

# %%
# Adding new columns using "ALP_LabelsForPython"
ALP_labels = pd.read_excel("./data/infor_data/5. ALP_LabelsForPython.xlsx", 
                              sheet_name = "details", dtype = {'variable': float}, 
                              index_col = None)
ALP_labels = ALP_labels[ALP_labels['filter'] == 'label']
list_old_columns = ALP_labels['old_column'].unique()
print(len(list_old_columns))
# Out:
# 99

# %%
## looping adding new columns
for i in list_old_columns:
    new_values = i
    i = ALP_labels[ALP_labels['old_column'] == i]
    df = df.merge(i[['variable', 'label']], left_on = new_values, 
                  right_on = 'variable', how = 'left')
    df[new_values] = df[new_values].fillna(10000)    
    df.drop(columns = {'variable'}, inplace = True)
    df.rename(columns = {'label': new_values + '_label'}, inplace = True)
    
    df.index = np.arange(1,len(df)+1)
    
#df.loc[df['literacy_label'].isnull(), 'literacy_label'] = '--*'

# %%
filename = "ALP_Chemtex_FullProcessedDataWithLabels.xlsx"
df.to_excel('./data/processed_data/{}'.format(filename), header = True, index = False)

# %%
import pandas as pd

# %%
df = pd.read_excel('./data/processed_data/ALP_Chemtex_FinalScores.xlsx', na_values = "NaN")

# %%
df.head()
# Out:
#    Unnamed: 0  cs_categ_scw  pts_categ_scw  pp_categ_scw  rmee_categ_scw  \
# 0           1             0              0             0               0
# 1           2            16              4             0               4
# 2           3            11             10            20               3
# 3           4             7              3             0               1
# 4           5            14             11             0               7
#
#    ofp_categ_scw  total_sc_final
# 0              0               0
# 1              0              24
# 2             20              64
# 3             10              21
# 4             20              52

# %%
# - 'total_scoring' = 3 categories, as follows:
#     - 1-33 Very immature, needs basic systems and mgmt pratices
#     - 34-66 Average application of mgmt systems and practices, can improve 
#        operational and financial performance
#     - 67+   Top performer, areas for improvement

# %%
Condition1=(df['total_sc_final']>=1) & (df['total_sc_final']<=33)
df1=df[Condition1]
df1.head()
# Out:
#    Unnamed: 0  cs_categ_scw  pts_categ_scw  pp_categ_scw  rmee_categ_scw  \
# 1           2            16              4             0               4
# 3           4             7              3             0               1
# 5           6             6              4             0               5
# 6           7             4              1             0               3
# 9          10            11              7             0               5
#
#    ofp_categ_scw  total_sc_final
# 1              0              24
# 3             10              21
# 5              5              20
# 6             10              18
# 9              5              28

# %%
df1.to_excel('./data/processed_data/ALP_Chemtex_FinalScores_bottom.xlsx')

# %%
Condition2=(df['total_sc_final']>=34) & (df['total_sc_final']<=66)
df2=df[Condition2]
df2.head()
# Out:
#     Unnamed: 0  cs_categ_scw  pts_categ_scw  pp_categ_scw  rmee_categ_scw  \
# 2            3            11             10            20               3
# 4            5            14             11             0               7
# 7            8            12              6             0               5
# 8            9            11             11            10               7
# 20          21            20             12             5               4
#
#     ofp_categ_scw  total_sc_final
# 2              20              64
# 4              20              52
# 7              15              38
# 8              20              59
# 20              5              46

# %%
df2.to_excel('./data/processed_data/ALP_Chemtex_FinalScores_middle.xlsx')

# %%
Condition3=(df['total_sc_final']>=67)
df3=df[Condition3]
df3.head()
# Out:
#      Unnamed: 0  cs_categ_scw  pts_categ_scw  pp_categ_scw  rmee_categ_scw  \
# 11           12            10             14            20              20
# 12           13            10             13            20              20
# 13           14            10             14            20              20
# 18           19            15             12            20               6
# 118         119            11             13            20              20
#
#      ofp_categ_scw  total_sc_final
# 11              20              84
# 12              20              83
# 13              20              84
# 18              15              68
# 118             20              84

# %%
df3.to_excel('./data/processed_data/ALP_Chemtex_FinalScores_top.xlsx')
